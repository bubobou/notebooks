# %% [markdown]
# <div style="display:flex; align-items:center; border: 2px dashed #f37726; border-left:15px solid #f37726; padding:15px; margin:15px">
#     <span style="font-size:200%; font-weight:bold; margin:50px;  color:#666; padding-left:0px;">
#     À la découverte de Jupyter
#     </span>
#
# </div>
#
#
# <img style="display: inline ; margin: 0 10% 0 20%" src="https://capytale2.ac-paris.fr/web/sites/default/files/2022/05-15/10-52-16/logo_Jupyter.svg" width="20%" />
#
#
# <img style="display: inline; margin: 0 10% 0 10%" src="https://capytale2.ac-paris.fr/web/sites/default/files/2022/05-15/10-52-16/logo_Capytale.svg" width="20%" />

# %% [markdown]
# <div class="alert alert-info" style="border-left:15px solid #31708f;font-size:150%;">
#     <b>Objectif.</b> Découvrir et apprendre à utiliser JUPYTER au travers de CAPYTALE.
# </div>

# %% [markdown]
# ## Présentations

# %% [markdown]
# ### Animateurs d'atelier
#
# **Qui ?** : Bruno Bourgine
#
# **Quoi ?** : Professeur de Mathématiques et Sciences Physiques en Lycée Professionnel
#
# **Où ?**
#  - LP J.B. Brochier (Marseille 10e)
#  - IREM : groupes enseignement de l'informatique

# %% [markdown]
# ## Au Menu
#
#  * [1. Qu'est-ce qui fait tourner Jupyter ?](#1.-Qu'est-ce-qui-fait-tourner-Jupyter-?)
#  * [2. Qu'est-ce qu'il y a dans un notebook ?](#2.-Qu'est-ce-qu'il-y-a-dans-un-notebook-?)
#  * [3. Comment utiliser Capytale](#3.-Comment-utiliser-Capytale-?)

# %% [markdown]
# ## En pratique
#
# - diaporama (notebook) disponible sur Capytale : [https://capytale2.ac-paris.fr](https://capytale2.ac-paris.fr)
#
# ou
#
# - basthon.fr : lien

# %% [markdown]
# ## 1. Qu'est-ce qui fait tourner Jupyter ?

# %% [markdown]
# ### 1.1 De quoi parle-t-on ?
#
# **Principe** : environnement de codage en python, interactif, et mis à disposition dans une page web.
#
# **Principe d'un notebook** : combiner des cellules contenant du code et des cellules contenant du texte plus ou moins enrichi.

# %% [markdown]
# Un exemple ?

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate random data-set
x = np.random.rand(100)
y = 3 * x + 2 + np.random.rand(100)

a, b, = np.polyfit(x, y, 1)

# plot
plt.figure()
plt.scatter(x, y, s=10)
plt.plot(x, a * x + b, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
#  **Historique :**
#
#  Le principe du notebook existait déjà avec *Mathematica* (1988).
#
#  Développement de Jupyter : IPython -> IPython Notebook -> Jupyter Notebook (début 2000)
#
#  Autre type de notebook utilisant Python : *SAGE* (devenu *SageMath*)

# %% [markdown]
# ### 1.2 Modèle client/serveur
#
# Le client est exécuté dans le navigateur de l'utilisateur, le serveur assure le dialogue entre un *kernel* et le fichier du notebook.
#
# Le *kernel* est un process qui exécute le code contenu dans le notebook à la demande du serveur. Le *kernel* n'a pas accès au fichier.

# %% [markdown]
# ![doc jupyter](https://docs.jupyter.org/en/latest/_images/notebook_components.png)

# %% [markdown]
# <div class="alert alert-warning" style="border-left:15px solid #8a6d3b;">
#     <b>Question :</b> où se cache le python ?
# </div>

# %% [markdown]
# ### 1.3 Comment utiliser Jupyter ?

# %% [markdown]
# Installer Jupyter à partir des sources : [https://jupyter.org/install](https://jupyter.org/install)
#
# Le serveur s'exécute sur votre poste, le notebook est accessible dans le navigateur.

# %% [markdown]
#  > On peut aussi installer un module dans un IDE (comme VSCode ou Codium).

# %% [markdown]
# Utiliser un outil clé en main : ![](https://basthon.fr/theme/assets/img/basthon.svg)
#
#
# - avec une connexion internet : [basthon.fr](basthon.fr)
# - sans connexion internet [Basthon-Desktop](https://basthon.fr/desktop.html)

# %% [markdown]
# <div class="alert alert-warning" style="border-left:15px solid #8a6d3b;">
#     <b>Question :</b> où se cache le python ?
# </div>

# %% [markdown]
# ## 2. Qu'est-ce qu'il y a dans un notebook ?

# %% [markdown]
# ### 2.1 format *ipynb* ?
#
# *ipynb* : **IPY**thon**N**ote**B**ook
#
# *ce que c'est* : un fichier contenant du texte au format JSON

# %% [markdown]
# ```json
# {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "<div class=\"alert alert-info\" style=\"border-left:15px solid #31708f;\">\n",
#     "    Compléter ci-dessous le code de la fonction permettant de déterminer l'étendue d'une série. (puis exécuter en appuyant sur [Maj]+[Entrée]) \n",
#     "</div>"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "def etendue(serie):\n",
#     "    return ..."
#    ]
#   },
# ```

# %% [markdown]
# ### 2.2 Cellules de code
#
# Comme dans un IDE classique :
#  - coloration syntaxique
#  - aide
#  - autocomplétion
#  - traitement des erreurs
#  - import de modules

# %% [markdown]
# ### 2.3 Cellules de texte
#
# Elles utilisent la syntaxe Markdown, mais peuvent aussi interpréter du HTML, ou du $\LaTeX$
#
# On peut y intégrer toute sorte de contenu web (page, video, [geogebra](https://capytale2.ac-paris.fr/wiki/doku.php?id=inserer_une_animation_geogebra), [code puzzle](https://www.codepuzzle.io/) ...) en important le module adéquat :
#
# ``` python
# from IPython.display import IFrame
# ```

# %%
from IPython.display import IFrame
IFrame("https://www.geogebra.org/material/iframe/id/yttknhqw/width/600/height/294/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/true/ctl/false",600,400)

# %% [markdown]
# ### 2.4 Exécuter des cellules
#
# Exécuter : interpréter le contenu de la cellule (texte ou code)
#
#  - bouton Exécuter  / MAJ+Entrée -> exécute puis passe à la cellule suivante
#  - CTRL+Entrée -> exécute mais reste sur la cellule

# %% [markdown]
# <div class="alert alert-warning" style="border-left:15px solid #8a6d3b;">
#     <b>Attention :</b>
#     <ul>
#         <li>les cellules de codes doivent être exécutées dans l'ordre.
#         <li>il faut réexécuter une cellule après modification (exemple : fonction)
#     </ul>
#
# </div>

# %% [markdown]
# ### 2.4 Métadonner des cellules
#
# Utiles pour bloquer le contenu d'une cellule et rendre sa modification impossible

# %% [markdown]
# ## 3. Comment publier, partager et évaluer avec Capytale ?

# %% [markdown]
# ### 3.1 **CaPYTale**, la recentralisation?
#
#  Utilise le noyau **Basthon** pour permettre aux utilisateurs des ENT de France de consulter et de créer des notebooks qui sont hébergés par l'académie de Paris.

# %% [markdown]
# ![fonctionnement Capytale](https://capytale2.ac-paris.fr/wiki/lib/exe/fetch.php?media=capture_d_ecran_de_2021-06-06_10-31-51.png)

# %% [markdown]
# ### 3.2 Quelques modules
#
# Sélection arbitraire de quelques modules d'intérêt pédagogique de visualistion du code et de son exécution.
#
# De très nombreux autres modules sont disponibles avec [Basthon](https://basthon.fr/galerie.html).

# %% [markdown]
# #### Lolviz (ListOFList Vizualisation)
#
# Permet de visualiser les structures de données (listes, dictionnaires, arbres...)

# %%
from lolviz import *
ma_liste = ['bonjour', 'le monde', {3, 4}, {"parrt":"user"}]

listviz(ma_liste)

# %%
mon_dico = {ord(c): c for c in 'abcdef'}

objviz(mon_dico)
objviz([ma_liste, mon_dico])

# %% [markdown]
# #### Pythontutor
#
# Permet de visualiser l'exécution d'un programme, et donc de mieux appréhender les notions de structures de données et d'espace mémoire.

# %%
from tutor import tutor

x = [1, 2, 3, 'bonjour', False, None]
y = {'Jeanne':100, 'Albert':21, 'Jacques':30}
z = set(x)
y['nested'] = x
x[1] = ['aa', 'bb', 'cc']

tutor()

# %% [markdown]
# #### Rcviz
#
# Pour visualiser des appels récursifs

# %%
from rcviz import viz
@viz
def quicksort(items):
    if len(items) <= 1:
        return items
    else:
        pivot = items[0]
        lesser = quicksort([x for x in items[1:] if x < pivot])
        greater = quicksort([x for x in items[1:] if x >= pivot])
        return lesser + [pivot] + greater
    
quicksort(list("helloworld"))
quicksort.callgraph()

# %% [markdown]
# ### 3.3 Les types d'activités disponibles sur CaPYTale

# %% [markdown]
# **Codage sans notebook :**
#  - Script-Console
#
# **Notebook avec d'autres langages :**
#
#  - notebook avec SQL
#  - notebook avec OCaml
#
# **Programmation par bloc :**
#  - PIXEL'Art
#  - à venir : Block2Py ?

# %% [markdown]
# ### 3.4 La bibliothèque d'activités

# %% [markdown]
# On peut choisir de mettre les activités à disposition des collègues dans la bibliothèque.
#
# Les critères de recherches sont :
#  - description
#  - enseignement
#
# Principe :
#  - consultation
#  - copie dans ses activités

# %% [markdown]
# ### 3.5 Gérer les travaux d'élèves

# %% [markdown]
# #### Partage
#
# Lors de la création d'un notebook : cocher partageable avec la classe.
#
# Récupérer le lien et le mettre à disposition des élèves via l'ENT.

# %% [markdown]
# #### Suivre et évaluer
#
# Dans l'interface, cliquer sur le nombres de vues
#
# Pour chaque élève, on peut ouvrir son notebook, le corriger et modifier son état

# %% [markdown]
# #### Inconvénients
#
# - Attention aux modifications du notebook !
#
# - La correction peut être fastidieuse (évolution prévue)
